# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import torch
from torch.distributions import Normal, Uniform, Gamma

# %%
target_distribution = Gamma(concentration=1.5, rate=1)
target_sample = target_distribution.sample([128])
plt.plot(np.linspace(0, 40, 1000), target_distribution.log_prob(torch.linspace(0.000, 40, 1000)).exp().tolist(), label='Target')
plt.legend()
# plt.xticks(np.linspace(0.001, 20, 1))
